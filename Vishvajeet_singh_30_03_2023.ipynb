# %%
# %pip install --upgrade plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 48.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.13.1
#     Uninstalling plotly-5.13.1:
#       Successfully uninstalled plotly-5.13.1
# ...

# %% [markdown]
# Intall package with country code

# %%
# %pip install iso3166
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Important packages

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

from iso3166 import countries
from datetime import datetime, timedelta

# %% [markdown]
# ##**Part 0 : Reading the data**

# %% [markdown]
# 1.   Please find the data (unemployment_analysis.csv) and take it as the input ( as data frame ).
# 2.   For all columns (having years), convert the strings into floats. (for e.g., 6.8 lacs 🡪 6.8)
# 3.   Display the column names along with their datatypes.
# 4.   Generate the unique country names along with their corresponding country code.
# 5.   Find total unemployed people for all the years for each country.

# %% [markdown]
# Solution 1

# %%
df_data = pd.read_csv("unemployment_analysis.csv")
df_data
# Out:
#                     Country Name Country Code        1991        1992  \
# 0    Africa Eastern and Southern          AFE    7.8 lacs   7.84 lacs
# 1                    Afghanistan          AFG  10.65 lacs  10.82 lacs
# 2     Africa Western and Central          AFW   4.42 lacs   4.53 lacs
# 3                         Angola          AGO   4.21 lacs   4.21 lacs
# 4                        Albania          ALB  10.31 lacs  30.01 lacs
# ..                           ...          ...         ...         ...
# 230                        Samoa          WSM    2.1 lacs   2.38 lacs
# 231                  Yemen, Rep.          YEM   8.32 lacs   8.31 lacs
# 232                 South Africa          ZAF  29.95 lacs  29.98 lacs
# 233                       Zambia          ZMB   18.9 lacs  19.37 lacs
# 234                     Zimbabwe          ZWE   4.94 lacs   4.99 lacs
#
#            1993        1994        1995        1996        1997        1998  \
# ...

# %% [markdown]
# Solution 2

# %%
df_data[['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']] = df_data[['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']].replace('lacs', '', regex=True).astype(float)

# %%
df_data
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %% [markdown]
# Solution 3

# %%
df_data.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %% [markdown]
# Solution 4

# %%
df_data[['Country Name', 'Country Code']]
# Out:
#                     Country Name Country Code
# 0    Africa Eastern and Southern          AFE
# 1                    Afghanistan          AFG
# 2     Africa Western and Central          AFW
# 3                         Angola          AGO
# 4                        Albania          ALB
# ..                           ...          ...
# 230                        Samoa          WSM
# 231                  Yemen, Rep.          YEM
# 232                 South Africa          ZAF
# 233                       Zambia          ZMB
# 234                     Zimbabwe          ZWE
#
# [235 rows x 2 columns]

# %% [markdown]
# Solution 5

# %%
df_data['total_unemployed_people']=df_data.sum(axis=1)
df_data
# Out:
# <ipython-input-11-63e663f6b133>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_data['total_unemployed_people']=df_data.sum(axis=1)
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# ...

# %% [markdown]
# ##**Part 1: Data Cleaning**
#
#
# *   Write a function called data_cleaning() which, when called, would perform the following activity:
#
#
#   1.   Find for any missing value in all the columns, display them.
# If any missing value exists, then replace them with the average of the corresponding country. Then, again, check for null values.
#
#   2.   For the countries ‘Benin’, ‘Bahrain’, find if any outliers exist. If yes, replace them with mean/median/mode.
#
#   3.   Create a new column, named, “Year”, which would have all the years as per each country & beside that column, add a new one named, “No. of unemployed”, which would have the corresponding total values.
#
#   4.   Change the column name “Country Name” to “Country_name” & “Country Code” to “Country_code”.
# Finally, this is how our data, after the changes, should look like: (this is only for reference)
# [Let’s call it df_pivot]

# %% [markdown]
# Solution 1

# %%
df_data[['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']].isna().values.sum()
# Out:
# 2

# %% [markdown]
# 1st missing value

# %%
col_subset = ['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
df_data.loc[df_data['2000'].isna()][col_subset]
# Out:
#      1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2012  \
# 228  1.68  1.69  1.73  1.59  1.74  1.72  1.68  1.76  1.78   NaN  ...  1.85
#
#      2013  2014  2015  2016  2017  2018  2019  2020  2021
# 228  1.86  1.81  1.86  1.78  1.75  1.81   1.8  2.12  2.18
#
# [1 rows x 31 columns]

# %% [markdown]
# 2nd missing value

# %%
col_subset = col_subset = ['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
df_data.loc[df_data['2015'].isna()][col_subset]
# Out:
#      1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...   2012  \
# 136  24.5  26.3  27.7  30.0  35.6  38.8  36.0  34.5  32.4  32.2  ...  31.02
#
#      2013   2014  2015   2016   2017   2018   2019  2020  2021
# 136  29.0  28.03   NaN  23.72  22.38  20.74  17.26  17.2  16.2
#
# [1 rows x 31 columns]

# %% [markdown]
# replace 1st NaN with avg of corresponding

# %%
avg_1=df_data.iloc[[228],[2, 33]].mean(axis=1)
print(avg_1)
df_data.iloc[[228], [11]] = df_data.iloc[[228], [11]].replace(np.nan, 27.79)
# Out:
# 228    27.79
# dtype: float64

# %% [markdown]
# replace 2nd value with avg of corresponding

# %%
avg_2=df_data.iloc[[136],[2, 33]].mean(axis=1)
print(avg_2)
df_data.iloc[[136], [26]]=df_data.iloc[[136], [26]].replace(np.nan, 460.955)
# Out:
# 136    460.955
# dtype: float64

# %% [markdown]
# Solution 2

# %%
df_data["Country Name"].isin(["Benin"]).any()
df_data["Country Name"].isin(["Bahrain"]).any()
# Out:
# True

# %% [markdown]
# Solution 3

# %% [markdown]
# Solution 4

# %%
df_data.columns.values[0:2] = ["Country_name", "Country_code"]

# %% [markdown]
# ###**Part 3:**
#
# 1.  Give the mean, median, mode & standard  deviation for the parameterized country over all the years. [e.g., descriptive_stats(‘WSM’) would give the descriptive statistics of this country.]
# 2.  Give the year during which the country’s (of the passed country_code) unemployment was minimum & maximum.
# 3. Find the top 5 countries which had maximum unemployment in 2021.
# 4. Find the top 3 countries that had unemployment greater than 5 lacs in the year 2021.
# 5. Calculate the change (in percentage) the countries (from ques. 3) saw in unemployment starting from 1991 to 2021 (year on year). [for e.g., change_1 = (1991_value – 1992_value.)/1991_value, change_2 = (1992_val – 1993_val)/1992_val & so on.]

# %% [markdown]
# Solution 1

# %%
descriptive_stats =df_data.describe()
descriptive_stats
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2013  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.550043  ...    8.086468
# ...

# %% [markdown]
# Solution 2

# %%
(f"Maximum value is: {df_data.max()['2015']}")
# Out:
# 'Maximum value is: 460.955'

# %%
(f"Minimum value is: {df_data.min()['2019']}")
# Out:
# 'Minimum value is: 0.1'

# %% [markdown]
# Solution 3

# %%
df_data[["2021", "Country Name"]].nlargest(5, "2021")
# Out:
#       2021        Country_name
# 232  33.56        South Africa
# 49   28.39            Djibouti
# 199  25.76            Eswatini
# 172  24.90  West Bank and Gaza
# 28   24.72            Botswana

# %% [markdown]
# Solution 4

# %%
df_data[df_data["2021"] >= 5].nlargest(3, "2021")
# Out:
#      Country_name Country_code   1991   1992   1993   1994   1995   1996  \
# 232  South Africa          ZAF  29.95  29.98  29.92  29.89  29.89  29.87
# 49       Djibouti          DJI  29.36  29.20  29.19  29.02  28.94  28.84
# 199      Eswatini          SWZ  21.81  21.76  21.73  21.71  21.65  22.08
#
#       1997   1998  ...   2013   2014   2015   2016   2017   2018   2019  \
# 232  29.91  29.95  ...  24.56  24.89  25.15  26.54  27.04  26.91  28.47
# 49   28.70  28.58  ...  26.64  26.48  26.33  26.19  26.06  26.19  26.36
# 199  22.50  23.08  ...  24.55  23.97  23.33  22.72  22.75  22.79  22.84
#
#       2020   2021  total_unemployed_people
# 232  29.22  33.56                   875.21
# 49   28.39  28.39                   859.73
# 199  25.51  25.76                   756.13
#
# [3 rows x 34 columns]

# %% [markdown]
# Solution 5

# %%
df_data["change_1"]=(abs(df_data["1991"]-df_data["1992"])/df_data["1991"])*100
df_data["change_2"]=(abs(df_data["1992"]-df_data["1993"])/df_data["1992"])*100
df_data["change_3"]=(abs(df_data["1993"]-df_data["1994"])/df_data["1993"])*100
df_data["change_4"]=(abs(df_data["1994"]-df_data["1995"])/df_data["1994"])*100
df_data["change_5"]=(abs(df_data["1995"]-df_data["1996"])/df_data["1995"])*100
df_data["change_6"]=(abs(df_data["1996"]-df_data["1997"])/df_data["1996"])*100
df_data["change_7"]=(abs(df_data["1997"]-df_data["1998"])/df_data["1997"])*100
df_data["change_8"]=(abs(df_data["1998"]-df_data["1999"])/df_data["1998"])*100
df_data["change_9"]=(abs(df_data["1999"]-df_data["2000"])/df_data["1999"])*100
df_data["change_10"]=(abs(df_data["2000"]-df_data["2001"])/df_data["2000"])*100
df_data["change_11"]=(abs(df_data["2001"]-df_data["2002"])/df_data["2001"])*100
df_data["change_12"]=(abs(df_data["2002"]-df_data["2003"])/df_data["2002"])*100
df_data["change_13"]=(abs(df_data["2003"]-df_data["2004"])/df_data["2003"])*100
df_data["change_14"]=(abs(df_data["2004"]-df_data["2005"])/df_data["2004"])*100
df_data["change_15"]=(abs(df_data["2005"]-df_data["2006"])/df_data["2005"])*100
df_data["change_16"]=(abs(df_data["2006"]-df_data["2007"])/df_data["2006"])*100
df_data["change_17"]=(abs(df_data["2007"]-df_data["2008"])/df_data["2007"])*100
df_data["change_18"]=(abs(df_data["2008"]-df_data["2009"])/df_data["2008"])*100
df_data["change_19"]=(abs(df_data["2009"]-df_data["2010"])/df_data["2009"])*100
df_data["change_20"]=(abs(df_data["2010"]-df_data["2011"])/df_data["2010"])*100
df_data["change_21"]=(abs(df_data["2011"]-df_data["2012"])/df_data["2011"])*100
df_data["change_22"]=(abs(df_data["2012"]-df_data["2013"])/df_data["2012"])*100
df_data["change_23"]=(abs(df_data["2013"]-df_data["2014"])/df_data["2013"])*100
df_data["change_24"]=(abs(df_data["2014"]-df_data["2015"])/df_data["2014"])*100
df_data["change_25"]=(abs(df_data["2015"]-df_data["2016"])/df_data["2015"])*100
df_data["change_26"]=(abs(df_data["2016"]-df_data["2017"])/df_data["2016"])*100
df_data["change_27"]=(abs(df_data["2017"]-df_data["2018"])/df_data["2017"])*100
df_data["change_28"]=(abs(df_data["2018"]-df_data["2019"])/df_data["2018"])*100
df_data["change_29"]=(abs(df_data["2019"]-df_data["2020"])/df_data["2019"])*100
df_data["change_30"]=(abs(df_data["2020"]-df_data["2021"])/df_data["2020"])*100

# %%
df_data
# Out:
#                     Country_name Country_code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...  change_21  change_22  change_23  \
# ...

# %% [markdown]
# ###**Part 4: Simple Machine Learning questions**
#
#
# *   Write a function called predict_future(‘how_many_consecutive_future_year_values_you_need’) -  that would –
# 1.   Predict the next 2 years’ values for all the countries. [i.e., for 2022 & 2023]
# [Use 2 models – Moving Average (take 3 months – for e.g., for 2005 = avg of (2002, 2003, 2004)) & ARIMA – for forecasting. Also, compare the MAPE of the 2 models.]
#
# 2.   Plot a line graph that would have the actual values we have in the dataset along with the forecasted values.
# 3.   For each year out of the 2 years (2022, 2023), find the maximum & minimum number of unemployed for each country.
# 4.   Find which forecasted year has the maximum overall unemployment.
# 5.   Find which countries’ unemployment in 2022 [which you’ll be forecasting] increased in comparison to 2021.

# %% [markdown]
# Solution 1

# %% [markdown]
# AR: Autoregression
#
# I: Integrated
#
# MA: Moving Average

# %%
plt.figure(figsize=(26,8))
series = df_data[df_data.columns[2:33]]
series.plot()
# Out:
# <Axes: >

# %% [markdown]
# Solution 2

# %% [markdown]
# Skipped

# %% [markdown]
# Solution 3

# %% [markdown]
# skipped

# %% [markdown]
# Solution 4

# %% [markdown]
# skipped

# %% [markdown]
# Solution 5

# %% [markdown]
# skipped

# %% [markdown]
# ###**Part 5: Visualization**
#
#
# *   Write a code to display the following graphs: (make sure the graphs are labelled properly.)
#
#
#   1.   A bar graph plotting the top 10 countries’ in unemployment in the year 2021.
#
#   2.   A line graph showing the percentage change in unemployment from 2000 to 2019 (year on year) for the top 5 countries that had maximum unemployment in 2021.
#   3.   A bar graph that would plot the top 3 countries in unemployment in 2021 along with their forecast in 2022.
#   4.   For the country code ‘WSM’, plot a line graph that would show us how the unemployment changed every 5 years. (like in 1991, 1996, ….)
#   5.   Please add any insights you could derive from all the graphs above.

# %% [markdown]
# Solution 1

# %%
top_10_countries_in_2021 = df_data[["Country_name", "2021"]].nlargest(10, "2021")
top_10_countries_in_2021.plot(x="Country_name", y="2021", kind="bar")
# Out:
# <Axes: xlabel='Country_name'>

# %% [markdown]
# Solution 2

# %%
unemployment_2000_to_2019_change = df_data.iloc[0, 44:63]
unemployment_2000_to_2019_change.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# Solution 3

# %%
top_3_countries_in_2021 = df_data[["Country_name", "2021"]].nlargest(3, "2021")
top_3_countries_in_2021.plot(x="Country_name", y="2021", kind="bar")
# Out:
# <Axes: xlabel='Country_name'>

# %% [markdown]
# Solution 4

# %%
wsm_data = df_data.loc[df_data['Country_code'] == 'WSM'].iloc[0, 2:33]
wsm_data.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# Solution 5

# %% [markdown]
# In 4th graph which is a line graph of unemployment, we can see every year unemployment numbers are getting increases.

# %% [markdown]
# ###**Part 6: About the previous Project**
#
#
# *   Please describe any interesting project you did in the Data Science domain in more than 300 words. Attach Github links if possible.

# %% [markdown]
# After learning some skills about data science, I worked on some projects, although it would be a bit difficult to tell that which project is interesting out of all the projects. But i would like tell about a project which is one of them that project name is Space Mission Analysis in which I worked on a lot of things. Whatever I analyzed, I would like to tell it in points.
#
#
#
# *   First i analyzed about some basics like shape of the data and their column names with duplicates and nan values.
#
# *  And after that removing all the junk data from the data made the entire data workable so that no error would occur while analyzing the data.
#
# *  By creating a bar chart of the data extracted number of launches per organization and found maximum and minimum number of launches per year and extrated information about active and retired rockets. Created a histogram graph which shows about all the expanses of each and every mission either its been successful or failed.
#
# *   By using a Choropleth Map Showd the Number of Launches by Country on the chart of world map. And by using Choropleth Map tried to show failure of the mission of countries and created a chart which showd the number of launches per country by organization.
# *   Analyzed the launches per month, Which months are most popular and least popular for launches and how the launches price varied over time.
#
# *   Extracted the information by creating a Chart the Number of Launches over Time of top organizations and analyzed cold war of us and ussr by creating plotly chart of missions and the growth percentage of organizations year on year.

# %% [markdown]
# **Github link of Space_Mission_Project_Analysis**
# https://github.com/vishi98/Data-Science-Project-Space-Analysis-Project-

# %% [markdown]
# ###**Part 7:  Time management**
#
#
# *   Can you please share your thoughts, in less than 120 words, on “If you get selected, how will you manage your time for this full-time internship opportunity”

# %% [markdown]
# Solution 7

# %% [markdown]
# I am mentioning some points by which I can do time management during my internship
#
# 1. By avoiding procrastination - Keeping the time in mind, I will try to complete the given work within time without delay.
# 2. By avoiding multitasking.
# 3. I will choose a dedicated work space to avoid distractions while I work.
# 4. I will take the help of seniors for the work which will be difficult for me, so that I will be able to do that work as soon as possible and By learning from I will be able to handle the problems that come next.
# 5. In my free time, I will try to know and learn more and more about my projects, so that I will be able to improve my work performance.
